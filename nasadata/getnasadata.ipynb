# %%
# !python getnasadata.py
# Out:
#  正在请求 NASA API (范围: 20241201-20251030)...
#                            YEAR  MO  DY  HR  ALLSKY_SFC_SW_DWN    T2M  WS2M
# index
# 2024-12-01 00:00:00+00:00  2024  12   1   0                0.0  15.38  1.23
# 2024-12-01 01:00:00+00:00  2024  12   1   1                0.0  15.09  1.28
# 2024-12-01 02:00:00+00:00  2024  12   1   2                0.0  14.71  1.36
# 2024-12-01 03:00:00+00:00  2024  12   1   3                0.0  14.04  1.51
# 2024-12-01 04:00:00+00:00  2024  12   1   4                0.0  13.37  1.64
# 数据已保存为 nasa_power_data.csv
